# %%
Titus remade db with all new species in it as well, redo gather with this

# %%
# location
/home/ctbrown/scratch3/sourmash-midgie-raker/outputs.ath/rename/gtdb+bins.species.sig.zip

# run gahter
srun --account=ctbrowngrp -p med2 -J rockdb -t 4:00:00 -c 32 --mem=80gb --pty bash

snakemake --use-conda --resources mem_mb=80000 --rerun-triggers mtime \
-c 32 --rerun-incomplete -k -s 251028gather_pangdb.smk -n
